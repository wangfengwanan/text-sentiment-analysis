# %%
import tensorflow as tf
import os
import sys
import numpy as np
import math
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score

tf.logging.set_verbosity(tf.logging.INFO)

# %%
def get_default_params():
    return tf.contrib.training.HParams(
        num_embedding_size = 120,
        num_timesteps = 100,
        num_fc_nodes = 64,
        batch_size = 128,
        clip_lstm_grads = 5.0,
        learning_rate = 0.001,
        num_word_threshold = 10,
    )

hps = get_default_params()

train_file = './senta_data/train.seg.txt'
val_file = './senta_data/val.seg.txt'
test_file = './senta_data/test.seg.txt'
vocab_file = './senta_data/vocab.txt'
category_file = './senta_data/category.txt'
model_path = './model/'

if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
class Vocab:
    def __init__(self, filename, num_word_threshold):
        self._word_to_id = {}
        self._unk = -1
        self._num_word_threshold = num_word_threshold
        self._read_dict(filename)
    
    def _read_dict(self, filename):
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        for line in lines:
            word, frequency = line.strip('\r\n').split('\t')
            frequency = int(frequency)
            if frequency < self._num_word_threshold:
                continue
            idx = len(self._word_to_id)
            if word == '<UNK>':
                self._unk = idx
            self._word_to_id[word] = idx
    
    def word_to_id(self, word):
        return self._word_to_id.get(word, self._unk)
    
    @property
    def unk(self):
        return self._unk
    
    def size(self):
        return len(self._word_to_id)
    
    def sentence_to_id(self, sentence):
        word_ids = [self.word_to_id(cur_word) \
                    for cur_word in sentence.split()]
        return word_ids\

class CategoryDict:
    def __init__(self, filename):
        self._category_to_id = {}
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        for line in lines:
            category = line.strip('\n')
            idx = len(self._category_to_id)
            self._category_to_id[category] = idx
    
    def size(self):
        return len(self._category_to_id)
        
    def category_to_id(self, category):
        if not category in self._category_to_id:
            print("%s is not in our category list" % category)
        return self._category_to_id[category]
    
vocab = Vocab(vocab_file, hps.num_word_threshold)
vocab_size = vocab.size()
tf.logging.info('vocab_size: %d' % vocab_size)

category_vocab = CategoryDict(category_file)
num_classes = category_vocab.size()
tf.logging.info('num_classes: %d' % num_classes)
test_str = '1'
tf.logging.info(
    'label: %s, id: %d' % (
        test_str,
        category_vocab.category_to_id(test_str)))
# Out:
# INFO:tensorflow:vocab_size: 4533
# INFO:tensorflow:num_classes: 2
# INFO:tensorflow:label: 1, id: 1

# %%
class TextDataSet:
    def __init__(self, filename, vocab, category_vocab, num_timesteps):
        self._vocab = vocab
        self._category_vocab = category_vocab
        self._num_timesteps = num_timesteps
        # matrix
        self._inputs = []
        # vector
        self._outputs = []
        self._indicator = 0
        self._parse_file(filename)
    
    def _parse_file(self, filename):
        tf.logging.info('Loading data from %s', filename)
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            c = 0
            for line in lines:
                c += 1
                line = line.strip('\n').split('\t')
                if len(line) < 2:
                    continue
                label, content = line[0], line[1]
                id_label = self._category_vocab.category_to_id(label)
                id_words = self._vocab.sentence_to_id(content)
                id_words = id_words[0: self._num_timesteps]
                padding_num = self._num_timesteps - len(id_words)
                id_words = id_words + [
                    self._vocab.unk for i in range(padding_num)]
                self._inputs.append(id_words)
                self._outputs.append(id_label)
            self._inputs = np.asarray(self._inputs, dtype = np.int32)
            self._outputs = np.asarray(self._outputs, dtype = np.int32)
            self._random_shuffle()
    
    def _random_shuffle(self):
        p = np.random.permutation(len(self._inputs))
        self._inputs = self._inputs[p]
        self._outputs = self._outputs[p]
    
    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size
        if end_indicator > len(self._inputs):
            self._random_shuffle()
            self._indicator = 0
            end_indicator = batch_size
        if end_indicator > len(self._inputs):
            print("batch_size: %d is too large" % batch_size)
        
        batch_inputs = self._inputs[self._indicator: end_indicator]
        batch_outputs = self._outputs[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_inputs, batch_outputs
            
train_dataset = TextDataSet(
    train_file, vocab, category_vocab, hps.num_timesteps) 
val_dataset = TextDataSet(
    val_file, vocab, category_vocab, hps.num_timesteps) 
test_dataset = TextDataSet(
    test_file, vocab, category_vocab, hps.num_timesteps)
# Out:
# INFO:tensorflow:Loading data from ../senta_data/train.seg.txt
# INFO:tensorflow:Loading data from ../senta_data/val.seg.txt
# INFO:tensorflow:Loading data from ../senta_data/test.seg.txt

# %%
def conv_wrapper(inputs, dilation_rate, name, output_channel=128, kernel_size=(1,3), activation=tf.nn.relu):
    conv = tf.layers.conv2d(inputs=inputs,
                            filters=output_channel,
                            kernel_size=kernel_size,
                            dilation_rate=dilation_rate,
                            padding='same',
                            activation=activation,
                            name=name)
    return conv

# %%
def conv_weight(name, shape):
    conv_weight = tf.get_variable(name, shape=shape, initializer=tf.contrib.layers.xavier_initializer())
    return conv_weight

# %%
def create_model(hps, vocab_size, num_classes):
    num_timesteps = hps.num_timesteps
    
    batch_size = tf.placeholder(tf.int32, [], name='batch_size')
    inputs = tf.placeholder(tf.int32, (None, num_timesteps), name='inputs')
    outputs = tf.placeholder(tf.int32, (None, ), name='outputs')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    is_training = tf.placeholder(tf.bool, name='is_training')
    
    global_step = tf.Variable(
        tf.zeros([], tf.int64), name = 'global_step', trainable=False)
    
    embedding_initializer = tf.random_uniform_initializer(-1.0, 1.0)
    with tf.variable_scope('embedding', initializer = embedding_initializer, reuse=tf.AUTO_REUSE):
        embeddings = tf.get_variable('embedding', 
                                     shape=[vocab_size, hps.num_embedding_size], 
                                     dtype=tf.float32)
        embed_inputs = tf.nn.embedding_lookup(embeddings, inputs)
    
    model_inputs = tf.expand_dims(embed_inputs, 1)
    with tf.variable_scope("conv", reuse=tf.AUTO_REUSE):
        conv1_1 = conv_wrapper(model_inputs, 1, 'conv1_1', kernel_size=(1,1))
        conv1_2 = conv_wrapper(model_inputs, 1, 'conv1_2', kernel_size=(1,2))
        conv1_3 = conv_wrapper(model_inputs, 1, 'conv1_3', kernel_size=(1,3))
        conv1_4 = conv_wrapper(model_inputs, 1, 'conv1_4', kernel_size=(1,5))
        conv1_5 = conv_wrapper(model_inputs, 1, 'conv1_5', kernel_size=(1,7))
        conv1 = tf.concat([conv1_1, conv1_2, conv1_3, conv1_4, conv1_5], axis=-1)
        conv2_1 = conv_wrapper(conv1, 1, 'conv2_1')
        conv2_2 = conv_wrapper(conv2_1, 1, 'conv2_2')
        conv2_3 = conv_wrapper(conv2_2, 2, 'conv2_3')
        conv3_1 = conv_wrapper(conv2_3, 1, 'conv3_1')
        conv3_2 = conv_wrapper(conv3_1, 1, 'conv3_2')
        conv3_3 = conv_wrapper(conv3_2, 2, 'conv3_3')
        conv4_1 = conv_wrapper(conv3_3, 1, 'conv4_1')
        conv4_2 = conv_wrapper(conv4_1, 1, 'conv4_2')
        conv4_3 = conv_wrapper(conv4_2, 2, 'conv4_3')
#         with tf.variable_scope('conv_weight', reuse=tf.AUTO_REUSE):
#             conv2_3_weight = conv_weight('conv2_3_weight', shape=conv2_3.get_shape()[1:])
#             conv3_3_weight = conv_weight('conv3_3_weight', shape=conv3_3.get_shape()[1:])
#             conv4_3_weight = conv_weight('conv4_3_weight', shape=conv4_3.get_shape()[1:])
#     conv2_3 = tf.multiply(conv2_3, conv2_3_weight)
#     conv3_3 = tf.multiply(conv3_3, conv3_3_weight)
#     conv4_3 = tf.multiply(conv4_3, conv4_3_weight)
#     tmp = tf.add(conv3_3, conv4_3)
#     last = tf.add(tmp, conv4_3)
    last = tf.concat([conv2_3, conv3_3, conv4_3], axis=3)
    with tf.variable_scope('flatten', reuse=tf.AUTO_REUSE):
        flatten = tf.layers.flatten(last)
    fc_init = tf.uniform_unit_scaling_initializer(factor=1.0)
    with tf.variable_scope('fc', initializer = fc_init, reuse=tf.AUTO_REUSE):
        fc1 = tf.layers.dense(flatten, 
                              hps.num_fc_nodes,
                              activation = tf.nn.relu,
                              name = 'fc1')
        fc1_dropout = tf.contrib.layers.dropout(fc1, keep_prob)
        logits = tf.layers.dense(fc1_dropout,
                                 num_classes,
                                 name = 'fc2')
    
    with tf.name_scope('metrics'):
        softmax_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits = logits, labels = outputs)
        loss = tf.reduce_mean(softmax_loss)
#         tf.nn.l2_loss(conv2_3_weight) + \
#         tf.nn.l2_loss(conv3_3_weight)
#         tf.nn.l2_loss(conv2_3_weight) + \
#         tf.nn.l2_loss(conv3_1_weight) + \
#         tf.nn.l2_loss(conv3_2_weight) + \
#         tf.nn.l2_loss(conv3_3_weight)
        # [0, 1, 5, 4, 2] -> argmax: 2
        y_pred = tf.argmax(tf.nn.softmax(logits),
                           1, 
                           output_type = tf.int32)
        correct_pred = tf.equal(outputs, y_pred)
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    with tf.variable_scope('train_op', reuse=tf.AUTO_REUSE):
        tvars = tf.trainable_variables()
        for var in tvars:
            tf.logging.info('variable name: %s' % (var.name))
        grads, _ = tf.clip_by_global_norm(
            tf.gradients(loss, tvars), hps.clip_lstm_grads)
        optimizer = tf.train.AdamOptimizer(hps.learning_rate)
        train_op = optimizer.apply_gradients(
            zip(grads, tvars), global_step = global_step)
    
    return ((inputs, outputs, keep_prob, batch_size, is_training),
            (loss, y_pred, accuracy),
            (train_op, global_step))

placeholders, metrics, others = create_model(
    hps, vocab_size, num_classes)

inputs, outputs, keep_prob, batch_size, is_training = placeholders
loss, y_pred, accuracy = metrics
train_op, global_step = others
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-7-07f1cce614a4>:49: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# INFO:tensorflow:variable name: embedding/embedding:0
# INFO:tensorflow:variable name: conv/conv1_1/kernel:0
# INFO:tensorflow:variable name: conv/conv1_1/bias:0
# INFO:tensorflow:variable name: conv/conv1_2/kernel:0
# INFO:tensorflow:variable name: conv/conv1_2/bias:0
# INFO:tensorflow:variable name: conv/conv1_3/kernel:0
# INFO:tensorflow:variable name: conv/conv1_3/bias:0
# INFO:tensorflow:variable name: conv/conv1_4/kernel:0
# INFO:tensorflow:variable name: conv/conv1_4/bias:0
# INFO:tensorflow:variable name: conv/conv1_5/kernel:0
# INFO:tensorflow:variable name: conv/conv1_5/bias:0
# INFO:tensorflow:variable name: conv/conv2_1/kernel:0
# INFO:tensorflow:variable name: conv/conv2_1/bias:0
# INFO:tensorflow:variable name: conv/conv2_2/kernel:0
# INFO:tensorflow:variable name: conv/conv2_2/bias:0
# INFO:tensorflow:variable name: conv/conv2_3/kernel:0
# INFO:tensorflow:variable name: conv/conv2_3/bias:0
# INFO:tensorflow:variable name: conv/conv3_1/kernel:0
# INFO:tensorflow:variable name: conv/conv3_1/bias:0
# INFO:tensorflow:variable name: conv/conv3_2/kernel:0
# INFO:tensorflow:variable name: conv/conv3_2/bias:0
# INFO:tensorflow:variable name: conv/conv3_3/kernel:0
# INFO:tensorflow:variable name: conv/conv3_3/bias:0
# INFO:tensorflow:variable name: conv/conv4_1/kernel:0
# INFO:tensorflow:variable name: conv/conv4_1/bias:0
# INFO:tensorflow:variable name: conv/conv4_2/kernel:0
# INFO:tensorflow:variable name: conv/conv4_2/bias:0
# INFO:tensorflow:variable name: conv/conv4_3/kernel:0
# INFO:tensorflow:variable name: conv/conv4_3/bias:0
# INFO:tensorflow:variable name: fc/fc1/kernel:0
# INFO:tensorflow:variable name: fc/fc1/bias:0
# INFO:tensorflow:variable name: fc/fc2/kernel:0
# INFO:tensorflow:variable name: fc/fc2/bias:0

# %%
init_op = tf.global_variables_initializer()
train_keep_prob_value = 0.6
test_keep_prob_value = 1.0

num_train_steps = 5000

with tf.Session() as sess:
    sess.run(init_op)
#     if os.path.exists('../model/checkpoint'):
# #         saver.restore(sess,FLAGS.model_dir)
#         saver.restore(sess,'../model')
#     else:
    val_data, val_labels = val_dataset.next_batch(1200)
    test_data, test_labels = test_dataset.next_batch(1200)
    for i in range(num_train_steps):
        batch_inputs, batch_labels = train_dataset.next_batch(
                hps.batch_size)
        outputs_val = sess.run([loss, accuracy, train_op, global_step, outputs, y_pred],
                                   feed_dict = {
                                       inputs: batch_inputs,
                                       outputs: batch_labels,
                                       keep_prob: train_keep_prob_value,
                                       batch_size: hps.batch_size,
                                       is_training: True
                                   })
        loss_val, accuracy_val, _, global_step_val, outputs_val, y_pred_val = outputs_val
        train_auc = roc_auc_score(outputs_val, y_pred_val)
        if (global_step_val + 1) % 100 == 0:
            outputs_ = sess.run([loss, accuracy, global_step, outputs, y_pred],
                                   feed_dict = {
                                       inputs: val_data,
                                       outputs: val_labels,
                                       keep_prob: test_keep_prob_value,
                                       batch_size: len(val_data),
                                       is_training: False
                                   })
            loss_, accuracy_, global_step_, outputs_, y_pred_ = outputs_
            val_auc = roc_auc_score(outputs_, y_pred_)
            tf.logging.info("[Val] Step: %5d, loss: %3.3f, accuracy: %3.3f, auc: %3.3f"
                                % (global_step_, loss_, accuracy_, val_auc))
            outputs_1 = sess.run([loss, accuracy, global_step, outputs, y_pred],
                                   feed_dict = {
                                       inputs: test_data,
                                       outputs: test_labels,
                                       keep_prob: test_keep_prob_value,
                                       batch_size: len(test_data),
                                       is_training: False
                                   })
            loss_1, accuracy_1, global_step_1, outputs_1, y_pred_1 = outputs_1
            test_auc = roc_auc_score(outputs_1, y_pred_1)
            tf.logging.info("[Test] Step: %5d, loss: %3.3f, accuracy: %3.3f, auc: %3.3f"
                                % (global_step_1, loss_1, accuracy_1, test_auc))
            if accuracy_1 > 0.910:
                saver.save(sess,model_path)
        if global_step_val % 20 == 0:
            tf.logging.info("Step: %5d, loss: %3.3f, accuracy: %3.3f, auc: %3.3f"
                                % (global_step_val, loss_val, accuracy_val, train_auc))
# Out:
# INFO:tensorflow:Step:     0, loss: 0.699, accuracy: 0.461, auc: 0.484
# INFO:tensorflow:Step:    20, loss: 0.669, accuracy: 0.617, auc: 0.581
# INFO:tensorflow:Step:    40, loss: 0.651, accuracy: 0.578, auc: 0.581
# INFO:tensorflow:Step:    60, loss: 0.577, accuracy: 0.719, auc: 0.710
# INFO:tensorflow:Step:    80, loss: 0.488, accuracy: 0.750, auc: 0.752
# INFO:tensorflow:[Val] Step:   100, loss: 0.496, accuracy: 0.799, auc: 0.801
# INFO:tensorflow:[Test] Step:   100, loss: 0.499, accuracy: 0.798, auc: 0.796
# INFO:tensorflow:Step:   100, loss: 0.523, accuracy: 0.797, auc: 0.810
# INFO:tensorflow:Step:   120, loss: 0.500, accuracy: 0.773, auc: 0.765
# INFO:tensorflow:Step:   140, loss: 0.313, accuracy: 0.867, auc: 0.869
# INFO:tensorflow:Step:   160, loss: 0.353, accuracy: 0.844, auc: 0.846
# INFO:tensorflow:Step:   180, loss: 0.350, accuracy: 0.891, auc: 0.889
# INFO:tensorflow:[Val] Step:   200, loss: 0.262, accuracy: 0.912, auc: 0.912
# INFO:tensorflow:[Test] Step:   200, loss: 0.317, accuracy: 0.872, auc: 0.871
# INFO:tensorflow:Step:   200, loss: 0.312, accuracy: 0.891, auc: 0.892
# INFO:tensorflow:Step:   220, loss: 0.226, accuracy: 0.898, auc: 0.895
# INFO:tensorflow:Step:   240, loss: 0.127, accuracy: 0.953, auc: 0.953
# INFO:tensorflow:Step:   260, loss: 0.244, accuracy: 0.922, auc: 0.923
# INFO:tensorflow:Step:   280, loss: 0.292, accuracy: 0.898, auc: 0.898
# INFO:tensorflow:[Val] Step:   300, loss: 0.129, accuracy: 0.957, auc: 0.958
# INFO:tensorflow:[Test] Step:   300, loss: 0.334, accuracy: 0.887, auc: 0.887
# INFO:tensorflow:Step:   300, loss: 0.068, accuracy: 0.984, auc: 0.985
# INFO:tensorflow:Step:   320, loss: 0.097, accuracy: 0.969, auc: 0.968
# INFO:tensorflow:Step:   340, loss: 0.184, accuracy: 0.945, auc: 0.946
# INFO:tensorflow:Step:   360, loss: 0.075, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:   380, loss: 0.109, accuracy: 0.977, auc: 0.977
# INFO:tensorflow:[Val] Step:   400, loss: 0.074, accuracy: 0.978, auc: 0.978
# INFO:tensorflow:[Test] Step:   400, loss: 0.391, accuracy: 0.906, auc: 0.906
# INFO:tensorflow:Step:   400, loss: 0.140, accuracy: 0.953, auc: 0.954
# INFO:tensorflow:Step:   420, loss: 0.139, accuracy: 0.953, auc: 0.955
# INFO:tensorflow:Step:   440, loss: 0.212, accuracy: 0.938, auc: 0.944
# INFO:tensorflow:Step:   460, loss: 0.050, accuracy: 0.977, auc: 0.979
# INFO:tensorflow:Step:   480, loss: 0.038, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:[Val] Step:   500, loss: 0.172, accuracy: 0.933, auc: 0.932
# INFO:tensorflow:[Test] Step:   500, loss: 0.529, accuracy: 0.847, auc: 0.848
# INFO:tensorflow:Step:   500, loss: 0.101, accuracy: 0.953, auc: 0.946
# INFO:tensorflow:Step:   520, loss: 0.023, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:   540, loss: 0.023, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:   560, loss: 0.023, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   580, loss: 0.032, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:[Val] Step:   600, loss: 0.022, accuracy: 0.993, auc: 0.993
# INFO:tensorflow:[Test] Step:   600, loss: 0.576, accuracy: 0.892, auc: 0.892
# INFO:tensorflow:Step:   600, loss: 0.009, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   620, loss: 0.025, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:   640, loss: 0.054, accuracy: 0.977, auc: 0.977
# INFO:tensorflow:Step:   660, loss: 0.025, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   680, loss: 0.009, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:   700, loss: 0.014, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:   700, loss: 0.455, accuracy: 0.904, auc: 0.904
# INFO:tensorflow:Step:   700, loss: 0.025, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:   720, loss: 0.011, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:   740, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   760, loss: 0.031, accuracy: 0.977, auc: 0.977
# INFO:tensorflow:Step:   780, loss: 0.029, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:[Val] Step:   800, loss: 0.010, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:   800, loss: 0.551, accuracy: 0.902, auc: 0.902
# INFO:tensorflow:Step:   800, loss: 0.009, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   820, loss: 0.029, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:   840, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   860, loss: 0.026, accuracy: 0.984, auc: 0.983
# INFO:tensorflow:Step:   880, loss: 0.017, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:[Val] Step:   900, loss: 0.006, accuracy: 0.998, auc: 0.997
# INFO:tensorflow:[Test] Step:   900, loss: 0.632, accuracy: 0.899, auc: 0.899
# INFO:tensorflow:Step:   900, loss: 0.020, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:   920, loss: 0.050, accuracy: 0.969, auc: 0.969
# INFO:tensorflow:Step:   940, loss: 0.011, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:   960, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:   980, loss: 0.007, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1000, loss: 0.008, accuracy: 0.995, auc: 0.995
# INFO:tensorflow:[Test] Step:  1000, loss: 0.608, accuracy: 0.904, auc: 0.904
# INFO:tensorflow:Step:  1000, loss: 0.073, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  1020, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1040, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1060, loss: 0.010, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1080, loss: 0.022, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  1100, loss: 0.012, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  1100, loss: 0.507, accuracy: 0.906, auc: 0.906
# INFO:tensorflow:Step:  1100, loss: 0.017, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  1120, loss: 0.042, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:Step:  1140, loss: 0.016, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  1160, loss: 0.020, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  1180, loss: 0.024, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  1200, loss: 0.027, accuracy: 0.993, auc: 0.992
# INFO:tensorflow:[Test] Step:  1200, loss: 0.765, accuracy: 0.897, auc: 0.898
# INFO:tensorflow:Step:  1200, loss: 0.047, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  1220, loss: 0.041, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  1240, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1260, loss: 0.013, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1280, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1300, loss: 0.010, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  1300, loss: 0.700, accuracy: 0.897, auc: 0.897
# INFO:tensorflow:Step:  1300, loss: 0.045, accuracy: 0.984, auc: 0.983
# INFO:tensorflow:Step:  1320, loss: 0.069, accuracy: 0.977, auc: 0.974
# INFO:tensorflow:Step:  1340, loss: 0.045, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  1360, loss: 0.007, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  1380, loss: 0.007, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:[Val] Step:  1400, loss: 0.014, accuracy: 0.995, auc: 0.995
# INFO:tensorflow:[Test] Step:  1400, loss: 0.871, accuracy: 0.906, auc: 0.906
# INFO:tensorflow:Step:  1400, loss: 0.062, accuracy: 0.984, auc: 0.982
# INFO:tensorflow:Step:  1420, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1440, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1460, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1480, loss: 0.016, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1500, loss: 0.009, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  1500, loss: 0.875, accuracy: 0.898, auc: 0.899
# INFO:tensorflow:Step:  1500, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1520, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1540, loss: 0.003, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1560, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1580, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1600, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  1600, loss: 1.128, accuracy: 0.904, auc: 0.904
# INFO:tensorflow:Step:  1600, loss: 0.012, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  1620, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1640, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1660, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1680, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1700, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  1700, loss: 1.097, accuracy: 0.897, auc: 0.898
# INFO:tensorflow:Step:  1700, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1720, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1740, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1760, loss: 0.074, accuracy: 0.961, auc: 0.965
# INFO:tensorflow:Step:  1780, loss: 0.007, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1800, loss: 0.010, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  1800, loss: 0.639, accuracy: 0.909, auc: 0.909
# INFO:tensorflow:Step:  1800, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1820, loss: 0.028, accuracy: 0.977, auc: 0.976
# INFO:tensorflow:Step:  1840, loss: 0.015, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  1860, loss: 0.018, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  1880, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  1900, loss: 0.006, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  1900, loss: 0.691, accuracy: 0.897, auc: 0.897
# INFO:tensorflow:Step:  1900, loss: 0.021, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1920, loss: 0.010, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  1940, loss: 0.035, accuracy: 0.977, auc: 0.976
# INFO:tensorflow:Step:  1960, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  1980, loss: 0.012, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:[Val] Step:  2000, loss: 0.007, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2000, loss: 0.895, accuracy: 0.907, auc: 0.907
# INFO:tensorflow:Step:  2000, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  2020, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2040, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2060, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2080, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  2100, loss: 0.005, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2100, loss: 0.930, accuracy: 0.908, auc: 0.908
# INFO:tensorflow:Step:  2100, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2120, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2140, loss: 0.012, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  2160, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2180, loss: 0.050, accuracy: 0.984, auc: 0.983
# INFO:tensorflow:[Val] Step:  2200, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2200, loss: 0.981, accuracy: 0.905, auc: 0.905
# INFO:tensorflow:Step:  2200, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2220, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2240, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2260, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2280, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  2300, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2300, loss: 0.991, accuracy: 0.905, auc: 0.905
# INFO:tensorflow:Step:  2300, loss: 0.008, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2320, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2340, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2360, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2380, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  2400, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2400, loss: 1.095, accuracy: 0.908, auc: 0.908
# INFO:tensorflow:Step:  2400, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2420, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2440, loss: 0.015, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  2460, loss: 0.009, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2480, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  2500, loss: 0.005, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  2500, loss: 1.008, accuracy: 0.898, auc: 0.898
# INFO:tensorflow:Step:  2500, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2520, loss: 0.014, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2540, loss: 0.017, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2560, loss: 0.826, accuracy: 0.883, auc: 0.885
# INFO:tensorflow:Step:  2580, loss: 0.058, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  2600, loss: 0.024, accuracy: 0.990, auc: 0.990
# INFO:tensorflow:[Test] Step:  2600, loss: 0.908, accuracy: 0.895, auc: 0.895
# INFO:tensorflow:Step:  2600, loss: 0.009, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2620, loss: 0.015, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  2640, loss: 0.072, accuracy: 0.969, auc: 0.970
# INFO:tensorflow:Step:  2660, loss: 0.031, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:Step:  2680, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  2700, loss: 0.007, accuracy: 0.994, auc: 0.994
# INFO:tensorflow:[Test] Step:  2700, loss: 0.829, accuracy: 0.907, auc: 0.907
# INFO:tensorflow:Step:  2700, loss: 0.014, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2720, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2740, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2760, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2780, loss: 0.026, accuracy: 0.977, auc: 0.977
# INFO:tensorflow:[Val] Step:  2800, loss: 0.005, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  2800, loss: 0.885, accuracy: 0.908, auc: 0.908
# INFO:tensorflow:Step:  2800, loss: 0.010, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  2820, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2840, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2860, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2880, loss: 0.076, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:[Val] Step:  2900, loss: 0.008, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  2900, loss: 0.880, accuracy: 0.898, auc: 0.899
# INFO:tensorflow:Step:  2900, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2920, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2940, loss: 0.003, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2960, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  2980, loss: 0.006, accuracy: 0.992, auc: 0.990
# INFO:tensorflow:[Val] Step:  3000, loss: 0.004, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  3000, loss: 1.098, accuracy: 0.906, auc: 0.906
# INFO:tensorflow:Step:  3000, loss: 0.007, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  3020, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3040, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3060, loss: 0.009, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3080, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  3100, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3100, loss: 1.155, accuracy: 0.905, auc: 0.905
# INFO:tensorflow:Step:  3100, loss: 0.012, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3120, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3140, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3160, loss: 0.021, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3180, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3200, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3200, loss: 1.206, accuracy: 0.908, auc: 0.907
# INFO:tensorflow:Step:  3200, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3220, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3240, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3260, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3280, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3300, loss: 0.006, accuracy: 0.996, auc: 0.996
# INFO:tensorflow:[Test] Step:  3300, loss: 1.388, accuracy: 0.903, auc: 0.903
# INFO:tensorflow:Step:  3300, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3320, loss: 0.016, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3340, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  3360, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3380, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3400, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3400, loss: 1.136, accuracy: 0.911, auc: 0.911
# INFO:tensorflow:Step:  3400, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3420, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3440, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3460, loss: 0.011, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:Step:  3480, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3500, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3500, loss: 1.308, accuracy: 0.907, auc: 0.907
# INFO:tensorflow:Step:  3500, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3520, loss: 0.011, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3540, loss: 0.007, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3560, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3580, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3600, loss: 0.004, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  3600, loss: 1.388, accuracy: 0.906, auc: 0.906
# INFO:tensorflow:Step:  3600, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3620, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  3640, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3660, loss: 0.010, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3680, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  3700, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3700, loss: 1.447, accuracy: 0.908, auc: 0.908
# INFO:tensorflow:Step:  3700, loss: 0.012, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  3720, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3740, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3760, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  3780, loss: 0.011, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  3800, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  3800, loss: 1.560, accuracy: 0.908, auc: 0.907
# INFO:tensorflow:Step:  3800, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3820, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3840, loss: 0.137, accuracy: 0.961, auc: 0.962
# INFO:tensorflow:Step:  3860, loss: 0.025, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  3880, loss: 0.048, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:[Val] Step:  3900, loss: 0.016, accuracy: 0.993, auc: 0.993
# INFO:tensorflow:[Test] Step:  3900, loss: 0.667, accuracy: 0.911, auc: 0.911
# INFO:tensorflow:Step:  3900, loss: 0.023, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  3920, loss: 0.021, accuracy: 0.984, auc: 0.986
# INFO:tensorflow:Step:  3940, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  3960, loss: 0.013, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  3980, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4000, loss: 0.009, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  4000, loss: 0.960, accuracy: 0.902, auc: 0.903
# INFO:tensorflow:Step:  4000, loss: 0.019, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  4020, loss: 0.007, accuracy: 0.992, auc: 0.990
# INFO:tensorflow:Step:  4040, loss: 0.027, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4060, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4080, loss: 0.022, accuracy: 0.984, auc: 0.985
# INFO:tensorflow:[Val] Step:  4100, loss: 0.007, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  4100, loss: 0.924, accuracy: 0.912, auc: 0.912
# INFO:tensorflow:Step:  4100, loss: 0.011, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  4120, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4140, loss: 0.013, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  4160, loss: 0.002, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4180, loss: 0.039, accuracy: 0.984, auc: 0.983
# INFO:tensorflow:[Val] Step:  4200, loss: 0.008, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  4200, loss: 1.038, accuracy: 0.899, auc: 0.900
# INFO:tensorflow:Step:  4200, loss: 0.013, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  4220, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4240, loss: 0.008, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4260, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4280, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4300, loss: 0.004, accuracy: 0.999, auc: 0.999
# INFO:tensorflow:[Test] Step:  4300, loss: 1.122, accuracy: 0.902, auc: 0.903
# INFO:tensorflow:Step:  4300, loss: 0.024, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4320, loss: 0.011, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4340, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4360, loss: 0.029, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  4380, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4400, loss: 0.004, accuracy: 0.999, auc: 0.999
# INFO:tensorflow:[Test] Step:  4400, loss: 0.798, accuracy: 0.910, auc: 0.910
# INFO:tensorflow:Step:  4400, loss: 0.012, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4420, loss: 0.017, accuracy: 0.992, auc: 0.991
# INFO:tensorflow:Step:  4440, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  4460, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4480, loss: 0.012, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:[Val] Step:  4500, loss: 0.012, accuracy: 0.994, auc: 0.994
# INFO:tensorflow:[Test] Step:  4500, loss: 1.205, accuracy: 0.901, auc: 0.900
# INFO:tensorflow:Step:  4500, loss: 0.094, accuracy: 0.977, auc: 0.977
# INFO:tensorflow:Step:  4520, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4540, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4560, loss: 0.014, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4580, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4600, loss: 0.003, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  4600, loss: 1.173, accuracy: 0.902, auc: 0.903
# INFO:tensorflow:Step:  4600, loss: 0.012, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  4620, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4640, loss: 0.004, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4660, loss: 0.011, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4680, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4700, loss: 0.004, accuracy: 0.997, auc: 0.997
# INFO:tensorflow:[Test] Step:  4700, loss: 0.965, accuracy: 0.910, auc: 0.910
# INFO:tensorflow:Step:  4700, loss: 0.006, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  4720, loss: 0.010, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4740, loss: 0.006, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4760, loss: 0.003, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4780, loss: 0.005, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4800, loss: 0.003, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  4800, loss: 1.271, accuracy: 0.907, auc: 0.907
# INFO:tensorflow:Step:  4800, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4820, loss: 0.012, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4840, loss: 0.015, accuracy: 0.992, auc: 0.993
# INFO:tensorflow:Step:  4860, loss: 0.017, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4880, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:[Val] Step:  4900, loss: 0.003, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  4900, loss: 1.152, accuracy: 0.907, auc: 0.907
# INFO:tensorflow:Step:  4900, loss: 0.001, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4920, loss: 0.011, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:Step:  4940, loss: 0.015, accuracy: 0.984, auc: 0.984
# INFO:tensorflow:Step:  4960, loss: 0.000, accuracy: 1.000, auc: 1.000
# INFO:tensorflow:Step:  4980, loss: 0.006, accuracy: 0.992, auc: 0.992
# INFO:tensorflow:[Val] Step:  5000, loss: 0.003, accuracy: 0.998, auc: 0.998
# INFO:tensorflow:[Test] Step:  5000, loss: 1.445, accuracy: 0.908, auc: 0.909
